# %%
from copy import copy, deepcopyimport numpyimport matplotlib.pyplot as pyplotimport theanoimport theano.tensor as T  #TODO(tpaine) remove this dependency, can be done by factoring out the cost theano equationfrom layers import layers, cc_layersimport utilimport datasets.unsupervised_dataset as unsupervised_datasettheano.config.floatX = 'float32'def orthogonalize(w):    # Orthogonalize square matrices.    # Or left orthogonalize overcomplete matrices.    # Simply gets an SVD decomposition, and sets the singular values to ones.    dim2, dim1 = w.shape    short = numpy.min((dim2, dim1))    u, s, v = numpy.linalg.svd(w)    S = numpy.zeros((dim2,dim1))    s = s/s    S[:short,:short] = numpy.diag(s)    w = numpy.dot(u,numpy.dot(S,v))    w = numpy.float32(w)    return wdef conv_orthogonalize(w, k=1.0):    # Reshape filters into a matrix    channels, width, height, filters = w.shape    w = w.reshape(channels*width*height, filters).transpose(1,0)    # Orthogonalize the matrix    w = orthogonalize(w)    # Contruct 2D hamming window    hamming1 = numpy.hamming(width)    hamming2 = numpy.hamming(height)    hamming = numpy.outer(hamming1, hamming2)    # Use it to mask the input to w    mask = numpy.tile(hamming[None,:,:], (channels,1,1))    mask = mask.reshape(channels*width*height)*k    m = numpy.diag(mask)    w = numpy.dot(w, m)    # Reshape the matrix into filters    w = w.transpose(1,0)    w =  w.reshape(channels, width, height, filters)    w = numpy.float32(w)    return wdef get_image(batch, i):    image = numpy.uint8(batch[:,:,:,i].transpose(1,2,0)/2.0*255.0)    return imageclass Model(object):    input = cc_layers.CudaConvnetInput2DLayer(128, 3, 96, 96)    conv1 = cc_layers.ACudaConvnetConv2DLayer(input,                                              n_filters=64,                                             filter_size=3,                                             weights_std=0.01,                                             init_bias_value=0.0,                                             pad=1)    _,x1,y1,_ = conv1.get_output_shape()    print x1    conv2 = cc_layers.ACudaConvnetConv2DLayer(conv1,                                              n_filters=128,                                             stride=2,                                             filter_size=3,                                             weights_std=0.01,                                             init_bias_value=0.0,                                             pad=1)    _,x2,y2,_ = conv2.get_output_shape()    print x2    conv3 = cc_layers.ACudaConvnetConv2DLayer(conv2,                                              n_filters=256,                                             stride=1,                                             filter_size=3,                                             weights_std=0.01,                                             init_bias_value=0.0,                                             pad=1)    c3,x3,y3,b3 = conv3.get_output_shape()    deconv4 = cc_layers.ACudaConvnetDeconv2DLayer(conv3,                                                 n_channels=128,                                                 stride=1,                                                 filter_size=3,                                                 weights_std=0.01,                                                 init_bias_value=0.0,                                                 shape=(x2,y2),                                                 pad=1)    deconv5 = cc_layers.ACudaConvnetDeconv2DLayer(deconv4,                                                 n_channels=64,                                                 stride=2,                                                 filter_size=3,                                                 weights_std=0.01,                                                 init_bias_value=0.0,                                                 shape=(x1,y1),                                                 pad=1)    output = cc_layers.ACudaConvnetDeconv2DLayer(deconv5,                                                 n_channels=3,                                                 filter_size=3,                                                 weights_std=0.01,                                                 init_bias_value=0.0,                                                 pad=1)        def __init__(self, name, path):        self.name = name        self.path = path        self.all_parameters_symbol = layers.all_parameters(self._get_output_layer())            # can switch to gen_updates_regular_momentum        self.learning_rate_symbol = theano.shared(numpy.array(0.01, dtype=theano.config.floatX))        # self.updates_symbol = layers.gen_updates_sgd(self._get_cost_symbol(),        #                                             self.all_parameters_symbol,        #                                             learning_rate=self.learning_rate_symbol)        self.updates_symbol = layers.gen_updates_regular_momentum(self._get_cost_symbol(),                                                                  self.all_parameters_symbol,                                                                  learning_rate=self.learning_rate_symbol,                                                                  momentum=0.9,                                                                  weight_decay=1e-5)                self.train_func = theano.function([self._get_input_symbol()],                                           self._get_cost_symbol(),                                           updates=self.updates_symbol)        self.eval_func = theano.function([self._get_input_symbol()],                                         self._get_cost_symbol())        self.prediction_func = theano.function([self._get_input_symbol()],                                          self._get_output_symbol())                self.conv_func = theano.function([self._get_input_symbol()],                                         self.conv3.output())    def _get_input_symbol(self):        return self.input.output()        def _get_output_symbol(self):        return self.output.output()        def _get_cost_symbol(self):        input = self._get_input_symbol()        output = self._get_output_symbol()        cost = T.mean((output - input) ** 2)        return cost    def _get_output_layer(self):        return self.output        def train(self, batch):        return self.train_func(batch)        def eval(self, batch):        return self.eval_func(batch)    def prediction(self, batch):        return self.prediction_func(batch)        def conv(self, batch):        return self.conv_func(batch)class ModelVisualizer(object):    def __init__(self, model):        self.input = cc_layers.CudaConvnetInput2DLayer(model.b3, model.x3, model.y3, model.c3)        self.deconv4 = cc_layers.ACudaConvnetDeconv2DLayer(self.input,                                                 n_channels=128,                                                 stride=1,                                                 filter_size=3,                                                 weights_std=0.01,                                                 init_bias_value=0.0,                                                 shape=(model.x2, model.y2),                                                 pad=1)        self.deconv4.W.set_value(model.deconv4.W.get_value())        self.deconv4.b.set_value(model.deconv4.b.get_value())        self.deconv5 = cc_layers.ACudaConvnetDeconv2DLayer(self.deconv4,                                                 n_channels=64,                                                 stride=2,                                                 filter_size=3,                                                 weights_std=0.01,                                                 init_bias_value=0.0,                                                 shape=(model.x1, model.y1),                                                 pad=1)        self.deconv5.W.set_value(model.deconv5.W.get_value())        self.deconv5.b.set_value(model.deconv5.b.get_value())        self.output = cc_layers.ACudaConvnetDeconv2DLayer(self.deconv5,                                                 n_channels=3,                                                 filter_size=3,                                                 weights_std=0.01,                                                 init_bias_value=0.0,                                                 pad=1)                self.output.W.set_value(model.output.W.get_value())        self.output.b.set_value(model.output.b.get_value())        self.prediction_func = theano.function([self._get_input_symbol()],                                          self._get_output_symbol())    def _get_input_symbol(self):        return self.input.output()        def _get_output_symbol(self):        return self.output.output()    def _get_output_layer(self):        return self.output    def prediction(self, batch):        return self.prediction_func(batch)
# Out:
# 9648

# %%
data = numpy.load('/data/stl10_matlab/unsupervised.npy')data = numpy.float32(data)data = data/255.0*2.0train_data = data[0:90000, :, :, :]test_data = data[90000::, :, :, :]

# %%
train_dataset = unsupervised_dataset.UnsupervisedDataset(train_data)test_dataset = unsupervised_dataset.UnsupervisedDataset(test_data)test_iterator = test_dataset.iterator(mode='sequential', batch_size=128)train_iterator = train_dataset.iterator(mode='random_uniform', batch_size=128, num_batches=100000)

# %%
model = Model('deconv-stl10-32x64', '/experiments/deconv/stl10-32x64-ortho')w1 = model.conv1.W.get_value()w2 = model.conv2.W.get_value()w3 = model.conv3.W.get_value()k = 1.05w1 = conv_orthogonalize(w1,k=k)w2 = conv_orthogonalize(w2,k=k)w3 = conv_orthogonalize(w3,k=k)# # Initialize the layers with orthogonal weightsmodel.conv1.W.set_value(w1)model.conv2.W.set_value(w2)model.conv3.W.set_value(w3)model.deconv4.W.set_value(w3)model.deconv5.W.set_value(w2)model.output.W.set_value(w1)

# %%
alpha = numpy.float32(1.0)model.conv1.alpha.set_value(alpha)model.conv2.alpha.set_value(alpha)model.conv3.alpha.set_value(alpha)model.deconv4.alpha.set_value(alpha)model.deconv5.alpha.set_value(alpha)model.output.alpha.set_value(alpha)

# %%
batch = test_iterator.next()batch = batch.transpose(1,2,3,0)print batch.shapebatch_hat = model.prediction(batch)batch_hat.shape#i = numpy.random.randint(128)
# Out:
# (3, 96, 96, 128)
# (3, 96, 96, 128)

# %%
model_vis = ModelVisualizer(model)conv = model.conv(batch)# Make and apply a maskmask = numpy.zeros((49,49),dtype=numpy.float32)mask[20:30,20:30] = 1mask_mat = numpy.tile(mask[None,:,:,None], (256,1,1,128))conv2 = conv*mask_mat# Back project down to image spacebatch_hat = model_vis.prediction(conv2)

# %%
i = numpy.random.randint(128)image = get_image(batch, i)image_hat = get_image(batch_hat, i)pyplot.imshow(numpy.hstack((image, image_hat)))pyplot.colorbar()pyplot.show()

# %%
pyplot.imshow(image_hat[:,:,0])pyplot.show()

# %%
train_dataset = unsupervised_dataset.UnsupervisedDataset(train_data)train_iterator = train_dataset.iterator(mode='random_uniform', batch_size=128, num_batches=100000)model.learning_rate_symbol.set_value(0.001)for batch in train_iterator:    batch = batch.transpose(1,2,3,0)    error = model.train(batch)    print error
# Out:
# 0.0006721992394890.000737960508559
# 0.000696192902979
# 0.000679073098581
# 0.000713328598067
# 0.000732590386178
# 0.000751155370381
# 0.000700756208971
# 0.000647471460979
# 0.000696476781741
# 0.000704934995156
# 0.000716707727406
# 0.000676146533806
# 0.000675587216392
# 0.000689234759193
# 0.000793407612946
# 0.000775947642978
# 0.000658664444927
# 0.000704186037183
# 0.000744788034353
# 0.000705242098775
# 0.000680707627907
# 0.000798099965323
# 0.000691599270795
# 0.000674765149597
# 0.000791028316598
# 0.000883355969563
# 0.000879076542333
# 0.000689286680426
# 0.000748939870391
# 0.000760971393902
# 0.000765068863984
# 0.000738683214877
# 0.000775707012508
# 0.000825019960757
# 0.000649703666568
# 0.000745614117477
# 0.000699411844835
# 0.000759983959142
# 0.000691296474542
# 0.000728208164219
# 0.000769036298152
# 0.000715196540114
# 0.000610285729636
# 0.000717633636668
# 0.000754164357204
# 0.000784522911999
# 0.000774910615291
# 0.00073148967931
# 0.000751837331336
# ...

# %%
filters = model.conv1.W.get_value()

# %%
numpy.zeros((3*64,3*64,3))#i = numpy.random.randint(64)#w = filters[:,:,:,i].transpose(1,2,0)#w -= numpy.min(w)#w /= numpy.max(w)#pyplot.imshow(w, interpolation='nearest')#pyplot.show()
# Out:
# 8.0

# %%
batch = test_iterator.next()batch = batch.transpose(1,2,3,0)batch_hat = model.prediction(batch)i = numpy.random.randint(128)image = get_image(batch, i)image_hat = get_image(batch_hat, i)pyplot.imshow(numpy.hstack((image, image_hat)))pyplot.colorbar()pyplot.show()
